# %%
pipeline = dlt.pipeline(
    pipeline_name="pokemon_api_pipeline",
    destination="postgres",
    dataset_name="pokemon_data",
)

# %%
df = pipeline.dataset().pokemon_details_api.df()
df
# Out:
# Running cells with 'data_load_script (3.13.5) (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/aarongilani/Dev_Arena/Python/data_load_script/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
